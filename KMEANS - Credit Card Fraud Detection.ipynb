# %% [markdown]
# # Credit Card Fraud Detection Using KMEANS

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.gridspec as gridspec
from collections import Counter
from sklearn import metrics
import numpy as np
# Out:
# /home/alvaro/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %% [markdown]
# ## Auxiliary functions

# %%
def plot_data(X, y):
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], 'k.', markersize=2)
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], 'r.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=30, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=50, linewidths=50,
                color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, y, resolution=1000, show_centroids=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')
    plot_data(X, y)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %% [markdown]
# ## 1. Reading the dataset

# %%
df = pd.read_csv("../datasets/CreditCardFraud/creditcard.csv")

# %% [markdown]
# ## 2. Information preview

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
print("Number of features:", len(df.columns))
print("Data set length:", len(df))
# Out:
# Number of features: 31
# Data set length: 284807

# %%
# 492 fraudulent transactions, 284315 legitimate transactions
# The dataset is unbalanced
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Visualization of the types of each of the attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Check if any column has null values
df.isna().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Graphic representation of the characteristics
features = df.drop("Class", axis=1)

plt.figure(figsize=(12,32))
gs = gridspec.GridSpec(8, 4)
gs.update(hspace=0.8)

for i, f in enumerate(features):
    ax = plt.subplot(gs[i])
    sns.histplot(df[f][df["Class"] == 1])
    sns.histplot(df[f][df["Class"] == 0])
    ax.set_xlabel('')
    ax.set_title('feature: ' + str(f))

plt.show()

# %%
# Graphic representation of two characteristics
plt.figure(figsize=(12, 6))
plt.scatter(df["V10"][df['Class'] == 0], df["V14"][df['Class'] == 0], c="g", marker=".")
plt.scatter(df["V10"][df['Class'] == 1], df["V14"][df['Class'] == 1], c="r", marker=".")
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()

# %% [markdown]
# ## 3. Dataset preparation

# %% [markdown]
# For this type of algorithm it is important that all the data is in a similar range, therefore, we can apply a scaling or normalization function.
# Another option is to eliminate features that are not in a similar range as long as they are not very influential for the prediction.

# %%
df = df.drop(["Time", "Amount"], axis=1)

# %% [markdown]
# ## 4. Kmeans with a two-dimensional dataset

# %% [markdown]
# Before starting the training of KMEANS for all the attributes of the data set, a test for two attributes is carried out in order to understand how it constructs the decision limit.

# %%
X = df[["V10", "V14"]].copy()
X
# Out:
#              V10       V14
# 0       0.090794 -0.311169
# 1      -0.166974 -0.143772
# 2       0.207643 -0.165946
# 3      -0.054952 -0.287924
# 4       0.753074 -1.119670
# ...          ...       ...
# 284802  4.356170  4.626942
# 284803 -0.975926 -0.675143
# 284804 -0.484782 -0.510602
# 284805 -0.399126  0.449624
# 284806 -0.915427 -0.084316
#
# [284807 rows x 2 columns]

# %%
# Clusters are generated for the unlabeled dataset
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(12, 6))
plot_decision_boundaries(kmeans, X.values, df["Class"].values)
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()

# %%
counter = Counter(clusters.tolist())
bad_counter = Counter(clusters[df['Class'] == 1].tolist())

for key in sorted(counter.keys()):
    print("Label {0} has {1} samples - {2} are malicious samples".format(
        key, counter[key], bad_counter[key]))
# Out:
# Label 0 has 65142 samples - 12 are malicious samples
# Label 1 has 27352 samples - 449 are malicious samples
# Label 2 has 120154 samples - 16 are malicious samples
# Label 3 has 69723 samples - 14 are malicious samples
# Label 4 has 2436 samples - 1 are malicious samples

# %% [markdown]
# ## 5. Kmeans with a multidimensional dataset

# %% [markdown]
# Being an algorithm based on unsupervised learning, the labels are not required to train or predict. Keep in mind that in this type of problem it is assumed that the labels are not available.

# %%
X = df.drop("Class", axis=1)
y = df["Class"].copy()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(X)

# %%
counter = Counter(clusters.tolist())
bad_counter = Counter(clusters[y == 1].tolist())

for key in sorted(counter.keys()):
    print("Label {0} has {1} samples - {2} are malicious samples".format(
        key, counter[key], bad_counter[key]))
# Out:
# Label 0 has 97604 samples - 138 are malicious samples
# Label 1 has 3566 samples - 12 are malicious samples
# Label 2 has 45512 samples - 2 are malicious samples
# Label 3 has 131987 samples - 137 are malicious samples
# Label 4 has 6138 samples - 203 are malicious samples

# %% [markdown]
# ## 6. Reduced number of features

# %% [markdown]
# In many cases Kmeans works best with a low number of features.

# %% [markdown]
# ### Feature Selection with Random Forest

# %%
# Random Forest is used for feature selection
from sklearn.ensemble import RandomForestClassifier

clf_rnd = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
clf_rnd.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)

# %%
# The most important characteristics are selected
feature_importances = {name: score for name, score in zip(list(df), clf_rnd.feature_importances_)}
feature_importances_sorted = pd.Series(feature_importances).sort_values(ascending=False)

# %%
# The dataset is reduced to the 7 most important characteristics
X_reduced = X[list(feature_importances_sorted.head(7).index)].copy()

# %%
X_reduced
# Out:
#              V17       V14       V16       V12       V10       V11       V18
# 0       0.207971 -0.311169 -0.470401 -0.617801  0.090794 -0.551600  0.025791
# 1      -0.114805 -0.143772  0.463917  1.065235 -0.166974  1.612727 -0.183361
# 2       1.109969 -0.165946 -2.890083  0.066084  0.207643  0.624501 -0.121359
# 3      -0.684093 -0.287924 -1.059647  0.178228 -0.054952 -0.226487  1.965775
# 4      -0.237033 -1.119670 -0.451449  0.538196  0.753074 -0.822843 -0.038195
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.991691  4.626942  1.107641  2.711941  4.356170 -1.593105  0.510632
# 284803 -0.025693 -0.675143 -0.711757  0.915802 -0.975926 -0.150189 -1.221179
# 284804  0.313502 -0.510602  0.140716  0.063119 -0.484782  0.411614  0.395652
# 284805  0.509928  0.449624 -0.608577 -0.962886 -0.399126 -1.933849  1.113981
# 284806 -0.660377 -0.084316 -0.302620 -0.031513 -0.915427 -1.040458  0.167430
#
# [284807 rows x 7 columns]

# %% [markdown]
# ## KMEANS training with the reduced dataset

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(X_reduced)

# %%
# The clusters and the content that have been formed are evaluated
counter = Counter(clusters.tolist())
bad_counter = Counter(clusters[y == 1].tolist())

for key in sorted(counter.keys()):
    print("Label {0} has {1} samples - {2} are malicious samples".format(
        key, counter[key], bad_counter[key]))
# Out:
# Label 0 has 100991 samples - 87 are malicious samples
# Label 1 has 46785 samples - 20 are malicious samples
# Label 2 has 20163 samples - 45 are malicious samples
# Label 3 has 116558 samples - 73 are malicious samples
# Label 4 has 310 samples - 267 are malicious samples

# %% [markdown]
# ## 7. Evaluation of the results

# %% [markdown]
# Care must be taken with unbalanced data sets when using metrics to measure the purity of clusters. One possible solution is to use dataset balancing techniques, such as generating more examples of fraudulent transactions or decreasing examples of legitimate transactions.
